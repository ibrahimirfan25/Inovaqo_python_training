# %%
# LISTS
fruits = ["apple", "banana", "mango"]

# Access
print(fruits[0], fruits[-1])
print(fruits[0:2])

# Update
fruits[1] = "orange"
fruits[0:2] = ["kiwi","grapes"]

# Add
fruits.append("pineapple")
fruits.insert(1, "melon")
fruits.extend(["strawberry","blueberry"])

# Remove
fruits.remove("kiwi")
fruits.pop(2)
del fruits[0]
fruits.clear()

# Loop
for f in fruits:
    print(f)
for i in range(len(fruits)):
    print(fruits[i])

# Copy
copy_nums = nums[:]
copy_nums2 = list(nums)

# Join
a = [1,2,3]
b = [4,5,6]
c = a + b
a.extend(b)

# List Methods
nums.count(4)
nums.index(4)
nums.reverse()

# TUPLES
student = ("Ibrahim", 20, "Python")

# Access
print(student[0], student[-1])
print(student[0:2])

# Update workaround
temp = list(student)
temp[1] = 21
student = tuple(temp)

# Add
student = student + ("AI",)

# Unpack
name, age, course, *rest = student

# Loop
for x in student:
    print(x)

# Join
a = (1,2)
b = (3,4)
c = a + b

# Tuple Methods
t = (1,2,2,3)
t.count(2)
t.index(3)

# Namedtuple
from collections import namedtuple
Student = namedtuple("Student","name age course")
s = Student("Ali",20,"Python")
print(s.name,s.age,s.course)

# SETS
s = {1,2,3,4}

# Access
for x in s:
    print(x)
if 1 in s:
    print("Found")

# Add
s.add(5)
s.update([6,7,8])

# Remove
s.remove(2)
s.discard(10)
s.pop()
s.clear()

# Loop
for x in s:
    print(x)

# Join
a = {1,2,3}
b = {3,4,5}
c = a.union(b)
a.update(b)

# Copy
b = a.copy()

# Set Operators
a = {1,2,3,4}
b = {3,4,5,6}
print(a | b)   # union
print(a & b)   # intersection
print(a - b)   # difference
print(a ^ b)   # symmetric difference

# Set Methods
a.issubset(b)
a.issuperset(b)
a.isdisjoint({7,8})

# DICTIONARIES
student = {"name":"Ibrahim","age":20,"course":"Python"}

# Access
print(student["name"])
print(student.get("age"))

# Update
student["age"] = 21
student.update({"course":"AI"})

# Add
student["grade"] = "A+"
student.update({"city":"London"})

# Remove
student.pop("age")
student.popitem()
del student["grade"]
student.clear()

# Views
student = {"name":"Ibrahim","age":20,"course":"Python"}
print(student.keys())
print(student.values())
print(student.items())

# Loop
for k in student:
    print(k)
for v in student.values():
    print(v)
for k,v in student.items():
    print(k,v)

# Copy
copy_student = student.copy()
copy_student2 = dict(student)

# Nested Dictionary
students = {
    "student1":{"name":"Ibrahim","age":20},
    "student2":{"name":"Ali","age":21}
}
print(students["student1"]["name"])
students["student2"]["age"]=25

# Dictionary Methods
x = ("a","b","c")
y = dict.fromkeys(x,0)
student.setdefault("age",20)

# ARRAYS
import array as arr

numbers = arr.array('i',[10,20,30,40])

# Access
print(numbers[0])
print(numbers[-1])
print(numbers[1:3])

# Add
numbers.append(50)
numbers.insert(1,15)
numbers.extend([60,70])

# Remove
numbers.remove(20)
numbers.pop(2)
del numbers[0]
numbers = arr.array('i',[])

# Loop
for x in numbers:
    print(x)
i=0
while i<len(numbers):
    print(numbers[i])
    i+=1

# Copy
copy_numbers = numbers[:]
copy_numbers2 = arr.array(numbers.typecode,numbers)

# Reverse
numbers.reverse()
for x in reversed(numbers):
    print(x)

# Sort
numbers = arr.array('i',[4,1,3,2])
numbers = arr.array('i', sorted(numbers))

# Join
a = arr.array('i',[1,2,3])
b = arr.array('i',[4,5])
c = arr.array('i', a + b)
a.extend(b)

# Array Methods
numbers.count(2)
numbers.index(3)
numbers.typecode
numbers.buffer_info()
# Out:
# apple mango
# ['apple', 'banana']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 30
#      27     print(fruits[i])
#      29 # Copy
# ---> 30 copy_nums = nums[:]
#      31 copy_nums2 = list(nums)
#      33 # Join
#
# NameError: name 'nums' is not defined
